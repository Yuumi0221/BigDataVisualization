# %% [markdown]
# ## 读入数据

# %%
import csv

f_1=csv.reader(open('../../../sources/taxi/train.csv', 'r', newline=''))
data=list(f_1)

# %%
print(len(data))
# Out:
# 1710671

# %% [markdown]
# ## 将StartPoint坐标写入txt文件

# %%
f_txt=open('../total/StartPoint.txt','w')

pointList=[]
for i in range(2,len(data)-1):
    tmp_1=data[i][8].split('[')
    if (len(tmp_1)>2):
        tmp_2=tmp_1[2].split(']')
        tmp_3=tmp_2[0].split(',')

    pointList.append(tmp_3)
    
f_txt.write("[[")

f_txt.write(pointList[0][0])
f_txt.write(",")
f_txt.write(pointList[0][1])
f_txt.write("]")

for i in range(1,len(pointList)):
    f_txt.write(",[")
#     str=''.join(pointList[i])
#     f_txt.write(str)
    f_txt.write(pointList[i][0])
    f_txt.write(",")
    f_txt.write(pointList[i][1])
    f_txt.write("]")

f_txt.write("]")
f_txt.close()

# %% [markdown]
# ## 将StartPoint坐标写入csv文件

# %%
pointList_2=[]
for i in range(2,len(data)-1):
    tmp_1=data[i][8].split('[')
    if (len(tmp_1)>2):
        tmp_2=tmp_1[2].split(']')
        tmp_3=tmp_2[0].split(',')
        tmp_3.append('1')

    pointList_2.append(tmp_3)

# %%
print(pointList_2[0])
# Out:
# ['-8.639847', '41.159826', '1']

# %%
f_csv_write=csv.writer(open('../total/StartPoint.csv','w', newline=''))

    
L=['lng','lan','number']
f_csv_write.writerow(L)

for i in pointList_2:
    f_csv_write.writerow(i)

# %% [markdown]
# ## 时间戳处理
# 注意：时间戳函数是不受时区干扰的存储时间的格式，在解析的时候需要手动设置时区

# %%
import datetime as dt
import pandas as pd
import pytz

source = pd.read_csv("../../../sources/taxi/train.csv", sep=",", low_memory=False)
#source = pd.read_csv('train.csv', sep=',', low_memory=False)
#source.head()
no_poly_source = source.loc[:, source.columns != 'POLYLINE']
#no_poly_source = source.loc[:]
#no_poly_source.head()
miss_false_no_poly_source = no_poly_source[no_poly_source.MISSING_DATA == False]

miss_false_no_poly_source.head()
# Out:
#                TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0  1372636858620000589         C          NaN           NaN  20000589
# 1  1372637303620000596         B          NaN           7.0  20000596
# 2  1372636951620000320         C          NaN           NaN  20000320
# 3  1372636854620000520         C          NaN           NaN  20000520
# 4  1372637091620000337         C          NaN           NaN  20000337
#
#     TIMESTAMP DAY_TYPE  MISSING_DATA
# 0  1372636858        A         False
# 1  1372637303        A         False
# 2  1372636951        A         False
# 3  1372636854        A         False
# 4  1372637091        A         False

# %%
new_source = miss_false_no_poly_source.copy()
new_source['WEEK_DAY'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).weekday())
new_source['YEAR'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).year)
new_source['MONTH'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).month)
new_source['MONTH_DAY'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).day)
new_source['HOUR'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).hour)
new_source['DATE'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).date().isoformat())
new_source['DATE_DATE'] = new_source.TIMESTAMP.apply(lambda x: dt.datetime.utcfromtimestamp(x).date())
new_source.tail()
# Out:
#                      TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 1710665  1404171463620000698         C          NaN           NaN  20000698
# 1710666  1404171367620000670         C          NaN           NaN  20000670
# 1710667  1388745716620000264         C          NaN           NaN  20000264
# 1710668  1404141826620000248         B          NaN          12.0  20000248
# 1710669  1404157147620000079         B          NaN          34.0  20000079
#
#           TIMESTAMP DAY_TYPE  MISSING_DATA  WEEK_DAY  YEAR  MONTH  MONTH_DAY  \
# 1710665  1404171463        A         False         0  2014      6         30
# 1710666  1404171367        A         False         0  2014      6         30
# 1710667  1388745716        A         False         4  2014      1          3
# 1710668  1404141826        A         False         0  2014      6         30
# 1710669  1404157147        A         False         0  2014      6         30
#
#          HOUR        DATE   DATE_DATE
# 1710665    23  2014-06-30  2014-06-30
# 1710666    23  2014-06-30  2014-06-30
# 1710667    10  2014-01-03  2014-01-03
# 1710668    15  2014-06-30  2014-06-30
# 1710669    19  2014-06-30  2014-06-30

# %%
new_source.head()
# Out:
#                TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0  1372636858620000589         C          NaN           NaN  20000589
# 1  1372637303620000596         B          NaN           7.0  20000596
# 2  1372636951620000320         C          NaN           NaN  20000320
# 3  1372636854620000520         C          NaN           NaN  20000520
# 4  1372637091620000337         C          NaN           NaN  20000337
#
#     TIMESTAMP DAY_TYPE  MISSING_DATA  \
# 0  1372636858        A         False
# 1  1372637303        A         False
# 2  1372636951        A         False
# 3  1372636854        A         False
# 4  1372637091        A         False
#
#                                             POLYLINE  WEEK_DAY  YEAR  MONTH  \
# 0  [[-8.618643,41.141412],[-8.618499,41.141376],[...         0  2013      7
# 1  [[-8.639847,41.159826],[-8.640351,41.159871],[...         0  2013      7
# 2  [[-8.612964,41.140359],[-8.613378,41.14035],[-...         0  2013      7
# 3  [[-8.574678,41.151951],[-8.574705,41.151942],[...         0  2013      7
# 4  [[-8.645994,41.18049],[-8.645949,41.180517],[-...         0  2013      7
#
#    MONTH_DAY  HOUR        DATE   DATE_DATE
# 0          1     0  2013-07-01  2013-07-01
# 1          1     0  2013-07-01  2013-07-01
# 2          1     0  2013-07-01  2013-07-01
# 3          1     0  2013-07-01  2013-07-01
# 4          1     0  2013-07-01  2013-07-01

# %%
print(type(new_source))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(new_source.columns)
# Out:
# Index(['TRIP_ID', 'CALL_TYPE', 'ORIGIN_CALL', 'ORIGIN_STAND', 'TAXI_ID',
#        'TIMESTAMP', 'DAY_TYPE', 'MISSING_DATA', 'WEEK_DAY', 'YEAR', 'MONTH',
#        'MONTH_DAY', 'HOUR', 'DATE', 'DATE_DATE'],
#       dtype='object')

# %%
print(new_source['DATE'])
# Out:
# 0          2013-07-01
# 1          2013-07-01
# 2          2013-07-01
# 3          2013-07-01
# 4          2013-07-01
#               ...
# 1710665    2014-06-30
# 1710666    2014-06-30
# 1710667    2014-01-03
# 1710668    2014-06-30
# 1710669    2014-06-30
# Name: DATE, Length: 1710660, dtype: object

# %% [markdown]
# #### 将pandas.DataFram格式的数据转化为列表的形式

# %%
new_source_list=new_source.values.tolist()
new_source_list
# Out:
# [[1372636858620000589,
#   'C',
#   nan,
#   nan,
#   20000589,
#   1372636858,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637303620000596,
#   'B',
#   nan,
#   7.0,
#   20000596,
#   1372637303,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372636951620000320,
#   'C',
#   nan,
#   nan,
#   20000320,
#   1372636951,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372636854620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372636854,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637091620000337,
#   'C',
#   nan,
#   nan,
#   20000337,
#   1372637091,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372636965620000231,
#   'C',
#   nan,
#   nan,
#   20000231,
#   1372636965,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637210620000456,
#   'C',
#   nan,
#   nan,
#   20000456,
#   1372637210,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637299620000011,
#   'C',
#   nan,
#   nan,
#   20000011,
#   1372637299,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637274620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372637274,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637905620000320,
#   'C',
#   nan,
#   nan,
#   20000320,
#   1372637905,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372636875620000233,
#   'C',
#   nan,
#   nan,
#   20000233,
#   1372636875,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637984620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372637984,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637343620000571,
#   'A',
#   31508.0,
#   nan,
#   20000571,
#   1372637343,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638595620000233,
#   'C',
#   nan,
#   nan,
#   20000233,
#   1372638595,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638151620000231,
#   'C',
#   nan,
#   nan,
#   20000231,
#   1372638151,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637610620000497,
#   'B',
#   nan,
#   13.0,
#   20000497,
#   1372637610,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638481620000403,
#   'B',
#   nan,
#   28.0,
#   20000403,
#   1372638481,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639135620000570,
#   'A',
#   33180.0,
#   nan,
#   20000570,
#   1372639135,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637482620000005,
#   'C',
#   nan,
#   nan,
#   20000005,
#   1372637482,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639181620000089,
#   'C',
#   nan,
#   nan,
#   20000089,
#   1372639181,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638161620000423,
#   'C',
#   nan,
#   nan,
#   20000423,
#   1372638161,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637254620000657,
#   'A',
#   39233.0,
#   nan,
#   20000657,
#   1372637254,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638502620000320,
#   'C',
#   nan,
#   nan,
#   20000320,
#   1372638502,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639960620000309,
#   'B',
#   nan,
#   38.0,
#   20000309,
#   1372639960,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637658620000596,
#   'A',
#   22864.0,
#   nan,
#   20000596,
#   1372637658,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639092620000233,
#   'C',
#   nan,
#   nan,
#   20000233,
#   1372639092,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639535620000161,
#   'A',
#   25862.0,
#   nan,
#   20000161,
#   1372639535,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640499620000596,
#   'C',
#   nan,
#   nan,
#   20000596,
#   1372640499,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639635620000178,
#   'B',
#   nan,
#   52.0,
#   20000178,
#   1372639635,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640555620000235,
#   'C',
#   nan,
#   nan,
#   20000235,
#   1372640555,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639871620000653,
#   'C',
#   nan,
#   nan,
#   20000653,
#   1372639871,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639875620000009,
#   'C',
#   nan,
#   nan,
#   20000009,
#   1372639875,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637453620000648,
#   'C',
#   nan,
#   nan,
#   20000648,
#   1372637453,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640399620000320,
#   'C',
#   nan,
#   nan,
#   20000320,
#   1372640399,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639558620000005,
#   'C',
#   nan,
#   nan,
#   20000005,
#   1372639558,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639848620000424,
#   'C',
#   nan,
#   nan,
#   20000424,
#   1372639848,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640130620000010,
#   'A',
#   4082.0,
#   nan,
#   20000010,
#   1372640130,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638902620000372,
#   'C',
#   nan,
#   nan,
#   20000372,
#   1372638902,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639973620000686,
#   'B',
#   nan,
#   23.0,
#   20000686,
#   1372639973,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638165620000435,
#   'C',
#   nan,
#   nan,
#   20000435,
#   1372638165,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640356620000657,
#   'B',
#   nan,
#   22.0,
#   20000657,
#   1372640356,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638793620000571,
#   'A',
#   2002.0,
#   nan,
#   20000571,
#   1372638793,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638361620000154,
#   'C',
#   nan,
#   nan,
#   20000154,
#   1372638361,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639857620000089,
#   'C',
#   nan,
#   nan,
#   20000089,
#   1372639857,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639096620000231,
#   'C',
#   nan,
#   nan,
#   20000231,
#   1372639096,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639536620000570,
#   'A',
#   25862.0,
#   nan,
#   20000570,
#   1372639536,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639241620000060,
#   'C',
#   nan,
#   nan,
#   20000060,
#   1372639241,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640943620000596,
#   'C',
#   nan,
#   nan,
#   20000596,
#   1372640943,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641991620000231,
#   'B',
#   nan,
#   13.0,
#   20000231,
#   1372641991,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641328620000005,
#   'C',
#   nan,
#   nan,
#   20000005,
#   1372641328,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641742620000657,
#   'B',
#   nan,
#   22.0,
#   20000657,
#   1372641742,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372636956620000167,
#   'C',
#   nan,
#   nan,
#   20000167,
#   1372636956,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641197620000653,
#   'B',
#   nan,
#   13.0,
#   20000653,
#   1372641197,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639521620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372639521,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642886620000403,
#   'B',
#   nan,
#   57.0,
#   20000403,
#   1372642886,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637230620000503,
#   'C',
#   nan,
#   nan,
#   20000503,
#   1372637230,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641690620000372,
#   'B',
#   nan,
#   23.0,
#   20000372,
#   1372641690,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638451620000621,
#   'A',
#   59594.0,
#   nan,
#   20000621,
#   1372638451,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642706620000653,
#   'B',
#   nan,
#   13.0,
#   20000653,
#   1372642706,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641749620000571,
#   'B',
#   nan,
#   34.0,
#   20000571,
#   1372641749,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642168620000570,
#   'C',
#   nan,
#   nan,
#   20000570,
#   1372642168,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639358620000463,
#   'C',
#   nan,
#   nan,
#   20000463,
#   1372639358,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642178620000060,
#   'C',
#   nan,
#   nan,
#   20000060,
#   1372642178,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641600620000612,
#   'B',
#   nan,
#   15.0,
#   20000612,
#   1372641600,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372636896620000360,
#   'C',
#   nan,
#   nan,
#   20000360,
#   1372636896,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643618620000463,
#   'B',
#   nan,
#   34.0,
#   20000463,
#   1372643618,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638641620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372638641,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641088620000574,
#   'C',
#   nan,
#   nan,
#   20000574,
#   1372641088,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637926620000173,
#   'C',
#   nan,
#   nan,
#   20000173,
#   1372637926,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641297620000320,
#   'C',
#   nan,
#   nan,
#   20000320,
#   1372641297,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641048620000560,
#   'A',
#   40433.0,
#   nan,
#   20000560,
#   1372641048,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643656620000492,
#   'C',
#   nan,
#   nan,
#   20000492,
#   1372643656,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641858620000154,
#   'A',
#   21875.0,
#   nan,
#   20000154,
#   1372641858,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638303620000112,
#   'A',
#   63882.0,
#   nan,
#   20000112,
#   1372638303,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642071620000305,
#   'C',
#   nan,
#   nan,
#   20000305,
#   1372642071,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644235620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372644235,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644270620000173,
#   'C',
#   nan,
#   nan,
#   20000173,
#   1372644270,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642569620000004,
#   'B',
#   nan,
#   18.0,
#   20000004,
#   1372642569,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638158620000620,
#   'C',
#   nan,
#   nan,
#   20000620,
#   1372638158,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637728620000671,
#   'C',
#   nan,
#   nan,
#   20000671,
#   1372637728,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637423620000341,
#   'C',
#   nan,
#   nan,
#   20000341,
#   1372637423,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639364620000015,
#   'C',
#   nan,
#   nan,
#   20000015,
#   1372639364,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644476620000307,
#   'C',
#   nan,
#   nan,
#   20000307,
#   1372644476,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641724620000435,
#   'C',
#   nan,
#   nan,
#   20000435,
#   1372641724,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638031620000171,
#   'C',
#   nan,
#   nan,
#   20000171,
#   1372638031,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639380620000201,
#   'A',
#   33597.0,
#   nan,
#   20000201,
#   1372639380,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637754620000007,
#   'C',
#   nan,
#   nan,
#   20000007,
#   1372637754,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639475620000199,
#   'C',
#   nan,
#   nan,
#   20000199,
#   1372639475,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638266620000611,
#   'C',
#   nan,
#   nan,
#   20000611,
#   1372638266,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642553620000167,
#   'C',
#   nan,
#   nan,
#   20000167,
#   1372642553,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641721620000686,
#   'B',
#   nan,
#   23.0,
#   20000686,
#   1372641721,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640550620000233,
#   'A',
#   23799.0,
#   nan,
#   20000233,
#   1372640550,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643195620000372,
#   'C',
#   nan,
#   nan,
#   20000372,
#   1372643195,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644253620000574,
#   'C',
#   nan,
#   nan,
#   20000574,
#   1372644253,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637715620000398,
#   'C',
#   nan,
#   nan,
#   20000398,
#   1372637715,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637247620000067,
#   'C',
#   nan,
#   nan,
#   20000067,
#   1372637247,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644655620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372644655,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644436620000112,
#   'C',
#   nan,
#   nan,
#   20000112,
#   1372644436,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642990620000503,
#   'B',
#   nan,
#   47.0,
#   20000503,
#   1372642990,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643825620000569,
#   'C',
#   nan,
#   nan,
#   20000569,
#   1372643825,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638513620000473,
#   'A',
#   63882.0,
#   nan,
#   20000473,
#   1372638513,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637072620000367,
#   'C',
#   nan,
#   nan,
#   20000367,
#   1372637072,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638616620000672,
#   'C',
#   nan,
#   nan,
#   20000672,
#   1372638616,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641886620000089,
#   'A',
#   22495.0,
#   nan,
#   20000089,
#   1372641886,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644642620000305,
#   'B',
#   nan,
#   9.0,
#   20000305,
#   1372644642,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372637397620000190,
#   'A',
#   2002.0,
#   nan,
#   20000190,
#   1372637397,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642204620000596,
#   'C',
#   nan,
#   nan,
#   20000596,
#   1372642204,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638504620000600,
#   'A',
#   4609.0,
#   nan,
#   20000600,
#   1372638504,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641278620000009,
#   'A',
#   27738.0,
#   nan,
#   20000009,
#   1372641278,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640331620000496,
#   'C',
#   nan,
#   nan,
#   20000496,
#   1372640331,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640408620000013,
#   'C',
#   nan,
#   nan,
#   20000013,
#   1372640408,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645575620000201,
#   'B',
#   nan,
#   30.0,
#   20000201,
#   1372645575,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645298620000307,
#   'B',
#   nan,
#   57.0,
#   20000307,
#   1372645298,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641453620000010,
#   'B',
#   nan,
#   51.0,
#   20000010,
#   1372641453,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644692620000173,
#   'C',
#   nan,
#   nan,
#   20000173,
#   1372644692,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646173620000686,
#   'B',
#   nan,
#   23.0,
#   20000686,
#   1372646173,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645426620000454,
#   'C',
#   nan,
#   nan,
#   20000454,
#   1372645426,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643201620000621,
#   'B',
#   nan,
#   38.0,
#   20000621,
#   1372643201,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644311620000492,
#   'C',
#   nan,
#   nan,
#   20000492,
#   1372644311,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646789620000534,
#   'C',
#   nan,
#   nan,
#   20000534,
#   1372646789,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642351620000005,
#   'C',
#   nan,
#   nan,
#   20000005,
#   1372642351,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641454620000195,
#   'B',
#   nan,
#   60.0,
#   20000195,
#   1372641454,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647120620000307,
#   'B',
#   nan,
#   9.0,
#   20000307,
#   1372647120,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643415620000653,
#   'B',
#   nan,
#   13.0,
#   20000653,
#   1372643415,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638851620000406,
#   'C',
#   nan,
#   nan,
#   20000406,
#   1372638851,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645859620000199,
#   'C',
#   nan,
#   nan,
#   20000199,
#   1372645859,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647913620000307,
#   'C',
#   nan,
#   nan,
#   20000307,
#   1372647913,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646710620000367,
#   'A',
#   52460.0,
#   nan,
#   20000367,
#   1372646710,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638137620000325,
#   'C',
#   nan,
#   nan,
#   20000325,
#   1372638137,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646627620000503,
#   'B',
#   nan,
#   12.0,
#   20000503,
#   1372646627,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645158620000015,
#   'B',
#   nan,
#   58.0,
#   20000015,
#   1372645158,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646292620000101,
#   'A',
#   8939.0,
#   nan,
#   20000101,
#   1372646292,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638342620000011,
#   'C',
#   nan,
#   nan,
#   20000011,
#   1372638342,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640577620000632,
#   'B',
#   nan,
#   18.0,
#   20000632,
#   1372640577,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646610620000112,
#   'C',
#   nan,
#   nan,
#   20000112,
#   1372646610,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647683620000492,
#   'B',
#   nan,
#   58.0,
#   20000492,
#   1372647683,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638560620000308,
#   'B',
#   nan,
#   nan,
#   20000308,
#   1372638560,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640078620000333,
#   'C',
#   nan,
#   nan,
#   20000333,
#   1372640078,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641041620000481,
#   'C',
#   nan,
#   nan,
#   20000481,
#   1372641041,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647636620000621,
#   'B',
#   nan,
#   58.0,
#   20000621,
#   1372647636,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646478620000398,
#   'B',
#   nan,
#   9.0,
#   20000398,
#   1372646478,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642438620000657,
#   'A',
#   30736.0,
#   nan,
#   20000657,
#   1372642438,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644011620000463,
#   'C',
#   nan,
#   nan,
#   20000463,
#   1372644011,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644302620000560,
#   'C',
#   nan,
#   nan,
#   20000560,
#   1372644302,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645102620000671,
#   'B',
#   nan,
#   25.0,
#   20000671,
#   1372645102,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646917620000190,
#   'A',
#   28382.0,
#   nan,
#   20000190,
#   1372646917,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645492620000171,
#   'B',
#   nan,
#   25.0,
#   20000171,
#   1372645492,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646650620000569,
#   'C',
#   nan,
#   nan,
#   20000569,
#   1372646650,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644406620000486,
#   'C',
#   nan,
#   nan,
#   20000486,
#   1372644406,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646454620000574,
#   'C',
#   nan,
#   nan,
#   20000574,
#   1372646454,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643923620000360,
#   'B',
#   nan,
#   14.0,
#   20000360,
#   1372643923,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642896620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372642896,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646982620000600,
#   'A',
#   36572.0,
#   nan,
#   20000600,
#   1372646982,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647050620000496,
#   'C',
#   nan,
#   nan,
#   20000496,
#   1372647050,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644458620000450,
#   'B',
#   nan,
#   33.0,
#   20000450,
#   1372644458,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643960620000545,
#   'C',
#   nan,
#   nan,
#   20000545,
#   1372643960,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642291620000231,
#   'C',
#   nan,
#   nan,
#   20000231,
#   1372642291,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649262620000496,
#   'C',
#   nan,
#   nan,
#   20000496,
#   1372649262,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646391620000233,
#   'A',
#   55499.0,
#   nan,
#   20000233,
#   1372646391,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648701620000333,
#   'B',
#   nan,
#   61.0,
#   20000333,
#   1372648701,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647797620000005,
#   'B',
#   nan,
#   25.0,
#   20000005,
#   1372647797,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644406620000154,
#   'B',
#   nan,
#   52.0,
#   20000154,
#   1372644406,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647382620000686,
#   'C',
#   nan,
#   nan,
#   20000686,
#   1372647382,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648526620000011,
#   'B',
#   nan,
#   23.0,
#   20000011,
#   1372648526,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641284620000648,
#   'B',
#   nan,
#   53.0,
#   20000648,
#   1372641284,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641068620000178,
#   'A',
#   52403.0,
#   nan,
#   20000178,
#   1372641068,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372641149620000235,
#   'B',
#   nan,
#   57.0,
#   20000235,
#   1372641149,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646864620000089,
#   'B',
#   nan,
#   36.0,
#   20000089,
#   1372646864,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649049620000671,
#   'B',
#   nan,
#   25.0,
#   20000671,
#   1372649049,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645157620000341,
#   'B',
#   nan,
#   9.0,
#   20000341,
#   1372645157,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647990620000653,
#   'C',
#   nan,
#   nan,
#   20000653,
#   1372647990,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648378620000325,
#   'B',
#   nan,
#   14.0,
#   20000325,
#   1372648378,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648345620000367,
#   'C',
#   nan,
#   nan,
#   20000367,
#   1372648345,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649185620000360,
#   'B',
#   nan,
#   25.0,
#   20000360,
#   1372649185,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647730620000534,
#   'C',
#   nan,
#   nan,
#   20000534,
#   1372647730,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640338620000423,
#   'B',
#   nan,
#   13.0,
#   20000423,
#   1372640338,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649008620000560,
#   'B',
#   nan,
#   25.0,
#   20000560,
#   1372649008,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649002620000463,
#   'B',
#   nan,
#   25.0,
#   20000463,
#   1372649002,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650050620000534,
#   'C',
#   nan,
#   nan,
#   20000534,
#   1372650050,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649562620000686,
#   'B',
#   nan,
#   23.0,
#   20000686,
#   1372649562,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648236620000307,
#   'C',
#   nan,
#   nan,
#   20000307,
#   1372648236,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638700620000665,
#   'C',
#   nan,
#   nan,
#   20000665,
#   1372638700,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644281620000320,
#   'B',
#   nan,
#   34.0,
#   20000320,
#   1372644281,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649198620000403,
#   'A',
#   8939.0,
#   nan,
#   20000403,
#   1372649198,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372639441620000012,
#   'C',
#   nan,
#   nan,
#   20000012,
#   1372639441,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648789620000621,
#   'B',
#   nan,
#   58.0,
#   20000621,
#   1372648789,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648838620000398,
#   'C',
#   nan,
#   nan,
#   20000398,
#   1372648838,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646651620000688,
#   'A',
#   43149.0,
#   nan,
#   20000688,
#   1372646651,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650711620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372650711,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650516620000307,
#   'B',
#   nan,
#   20.0,
#   20000307,
#   1372650516,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650895620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372650895,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649134620000540,
#   'B',
#   nan,
#   61.0,
#   20000540,
#   1372649134,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646879620000305,
#   'C',
#   nan,
#   nan,
#   20000305,
#   1372646879,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648404620000503,
#   'A',
#   23631.0,
#   nan,
#   20000503,
#   1372648404,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649231620000600,
#   'B',
#   nan,
#   25.0,
#   20000600,
#   1372649231,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650908620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372650908,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649081620000171,
#   'B',
#   nan,
#   25.0,
#   20000171,
#   1372649081,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650494620000686,
#   'C',
#   nan,
#   nan,
#   20000686,
#   1372650494,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649630620000011,
#   'C',
#   nan,
#   nan,
#   20000011,
#   1372649630,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647115620000201,
#   'B',
#   nan,
#   12.0,
#   20000201,
#   1372647115,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649121620000486,
#   'B',
#   nan,
#   25.0,
#   20000486,
#   1372649121,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649085620000569,
#   'C',
#   nan,
#   nan,
#   20000569,
#   1372649085,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649452620000436,
#   'C',
#   nan,
#   nan,
#   20000436,
#   1372649452,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645400620000435,
#   'B',
#   nan,
#   9.0,
#   20000435,
#   1372645400,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647564620000454,
#   'A',
#   38867.0,
#   nan,
#   20000454,
#   1372647564,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649288620000517,
#   'A',
#   63882.0,
#   nan,
#   20000517,
#   1372649288,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649178620000153,
#   'C',
#   nan,
#   nan,
#   20000153,
#   1372649178,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646567620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372646567,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647232620000173,
#   'A',
#   6654.0,
#   nan,
#   20000173,
#   1372647232,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372642546620000458,
#   'A',
#   25002.0,
#   nan,
#   20000458,
#   1372642546,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649313620000231,
#   'C',
#   nan,
#   nan,
#   20000231,
#   1372649313,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645583620000007,
#   'A',
#   24681.0,
#   nan,
#   20000007,
#   1372645583,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649323620000496,
#   'C',
#   nan,
#   nan,
#   20000496,
#   1372649323,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372645240620000577,
#   'A',
#   28382.0,
#   nan,
#   20000577,
#   1372645240,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650838620000398,
#   'C',
#   nan,
#   nan,
#   20000398,
#   1372650838,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648539620000632,
#   'B',
#   nan,
#   56.0,
#   20000632,
#   1372648539,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646810620000672,
#   'C',
#   nan,
#   nan,
#   20000672,
#   1372646810,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643424620000571,
#   'B',
#   nan,
#   42.0,
#   20000571,
#   1372643424,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650128620000423,
#   'C',
#   nan,
#   nan,
#   20000423,
#   1372650128,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372644996620000620,
#   'B',
#   nan,
#   14.0,
#   20000620,
#   1372644996,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651639620000517,
#   'A',
#   2002.0,
#   nan,
#   20000517,
#   1372651639,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646432620000105,
#   'C',
#   nan,
#   nan,
#   20000105,
#   1372646432,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649763620000235,
#   'B',
#   nan,
#   14.0,
#   20000235,
#   1372649763,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646490620000067,
#   'C',
#   nan,
#   nan,
#   20000067,
#   1372646490,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646419620000372,
#   'B',
#   nan,
#   36.0,
#   20000372,
#   1372646419,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643825620000612,
#   'B',
#   nan,
#   24.0,
#   20000612,
#   1372643825,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650298620000534,
#   'C',
#   nan,
#   nan,
#   20000534,
#   1372650298,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648677620000492,
#   'B',
#   nan,
#   58.0,
#   20000492,
#   1372648677,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649921620000367,
#   'A',
#   21482.0,
#   nan,
#   20000367,
#   1372649921,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646066620000167,
#   'A',
#   28382.0,
#   nan,
#   20000167,
#   1372646066,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646925620000596,
#   'A',
#   2002.0,
#   nan,
#   20000596,
#   1372646925,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648898620000128,
#   'A',
#   63882.0,
#   nan,
#   20000128,
#   1372648898,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649558620000154,
#   'A',
#   48712.0,
#   nan,
#   20000154,
#   1372649558,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649271620000450,
#   'C',
#   nan,
#   nan,
#   20000450,
#   1372649271,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650781620000621,
#   'B',
#   nan,
#   38.0,
#   20000621,
#   1372650781,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372640068620000616,
#   'C',
#   nan,
#   nan,
#   20000616,
#   1372640068,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651473620000454,
#   'A',
#   13265.0,
#   nan,
#   20000454,
#   1372651473,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649751620000178,
#   'B',
#   nan,
#   9.0,
#   20000178,
#   1372649751,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648496620000101,
#   'A',
#   40667.0,
#   nan,
#   20000101,
#   1372648496,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651034620000403,
#   'C',
#   nan,
#   nan,
#   20000403,
#   1372651034,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372653466620000403,
#   'B',
#   nan,
#   30.0,
#   20000403,
#   1372653466,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652617620000477,
#   'C',
#   nan,
#   nan,
#   20000477,
#   1372652617,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652978620000167,
#   'A',
#   2974.0,
#   nan,
#   20000167,
#   1372652978,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651101620000197,
#   'C',
#   nan,
#   nan,
#   20000197,
#   1372651101,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651472620000435,
#   'B',
#   nan,
#   9.0,
#   20000435,
#   1372651472,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650626620000665,
#   'C',
#   nan,
#   nan,
#   20000665,
#   1372650626,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651273620000486,
#   'B',
#   nan,
#   18.0,
#   20000486,
#   1372651273,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647704620000476,
#   'C',
#   nan,
#   nan,
#   20000476,
#   1372647704,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649868620000653,
#   'C',
#   nan,
#   nan,
#   20000653,
#   1372649868,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649124620000480,
#   'C',
#   nan,
#   nan,
#   20000480,
#   1372649124,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648688620000308,
#   'B',
#   nan,
#   52.0,
#   20000308,
#   1372648688,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648996620000657,
#   'A',
#   58137.0,
#   nan,
#   20000657,
#   1372648996,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651688620000173,
#   'B',
#   nan,
#   6.0,
#   20000173,
#   1372651688,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651027620000600,
#   'B',
#   nan,
#   23.0,
#   20000600,
#   1372651027,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651200620000011,
#   'B',
#   nan,
#   12.0,
#   20000011,
#   1372651200,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638156620000451,
#   'C',
#   nan,
#   nan,
#   20000451,
#   1372638156,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649558620000663,
#   'B',
#   nan,
#   14.0,
#   20000663,
#   1372649558,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372649918620000325,
#   'B',
#   nan,
#   57.0,
#   20000325,
#   1372649918,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652423620000620,
#   'B',
#   nan,
#   14.0,
#   20000620,
#   1372652423,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652323620000571,
#   'A',
#   53595.0,
#   nan,
#   20000571,
#   1372652323,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651427620000569,
#   'C',
#   nan,
#   nan,
#   20000569,
#   1372651427,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652486620000105,
#   'A',
#   23721.0,
#   nan,
#   20000105,
#   1372652486,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372653618620000197,
#   'B',
#   nan,
#   6.0,
#   20000197,
#   1372653618,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372654625620000569,
#   'C',
#   nan,
#   nan,
#   20000569,
#   1372654625,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651870620000007,
#   'A',
#   63882.0,
#   nan,
#   20000007,
#   1372651870,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372654229620000663,
#   'C',
#   nan,
#   nan,
#   20000663,
#   1372654229,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372655154620000386,
#   'C',
#   nan,
#   nan,
#   20000386,
#   1372655154,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   13,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650915620000540,
#   'C',
#   nan,
#   nan,
#   20000540,
#   1372650915,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652856620000367,
#   'C',
#   nan,
#   nan,
#   20000367,
#   1372652856,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652291620000672,
#   'A',
#   41672.0,
#   nan,
#   20000672,
#   1372652291,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652609620000561,
#   'B',
#   nan,
#   34.0,
#   20000561,
#   1372652609,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372643562620000570,
#   'A',
#   17343.0,
#   nan,
#   20000570,
#   1372643562,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   9,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650243620000463,
#   'A',
#   57270.0,
#   nan,
#   20000463,
#   1372650243,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372646923620000472,
#   'C',
#   nan,
#   nan,
#   20000472,
#   1372646923,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650904620000307,
#   'C',
#   nan,
#   nan,
#   20000307,
#   1372650904,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651896620000496,
#   'A',
#   59134.0,
#   nan,
#   20000496,
#   1372651896,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647874620000195,
#   'B',
#   nan,
#   60.0,
#   20000195,
#   1372647874,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651679620000520,
#   'C',
#   nan,
#   nan,
#   20000520,
#   1372651679,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651225620000201,
#   'A',
#   14191.0,
#   nan,
#   20000201,
#   1372651225,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372653624620000435,
#   'C',
#   nan,
#   nan,
#   20000435,
#   1372653624,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650696620000320,
#   'B',
#   nan,
#   nan,
#   20000320,
#   1372650696,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647224620000010,
#   'C',
#   nan,
#   nan,
#   20000010,
#   1372647224,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372654080620000308,
#   'B',
#   nan,
#   60.0,
#   20000308,
#   1372654080,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372654482620000571,
#   'C',
#   nan,
#   nan,
#   20000571,
#   1372654482,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651706620000458,
#   'A',
#   45071.0,
#   nan,
#   20000458,
#   1372651706,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372638035620000337,
#   'A',
#   39353.0,
#   nan,
#   20000337,
#   1372638035,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   8,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372650938620000305,
#   'A',
#   22582.0,
#   nan,
#   20000305,
#   1372650938,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372655153620000280,
#   'C',
#   nan,
#   nan,
#   20000280,
#   1372655153,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   13,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372647114620000013,
#   'B',
#   nan,
#   33.0,
#   20000013,
#   1372647114,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   10,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372648578620000112,
#   'C',
#   nan,
#   nan,
#   20000112,
#   1372648578,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   11,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651253620000565,
#   'B',
#   nan,
#   52.0,
#   20000565,
#   1372651253,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372653605620000167,
#   'C',
#   nan,
#   nan,
#   20000167,
#   1372653605,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372651844620000432,
#   'A',
#   12468.0,
#   nan,
#   20000432,
#   1372651844,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372656656620000280,
#   'C',
#   nan,
#   nan,
#   20000280,
#   1372656656,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   13,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652766620000534,
#   'C',
#   nan,
#   nan,
#   20000534,
#   1372652766,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372655268620000197,
#   'B',
#   nan,
#   6.0,
#   20000197,
#   1372655268,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   13,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372654879620000329,
#   'A',
#   32964.0,
#   nan,
#   20000329,
#   1372654879,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   13,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
# ...
#   False,
#   0,
#   2013,
#   7,
#   1,
#   14,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372663110620000484,
#   'C',
#   nan,
#   nan,
#   20000484,
#   1372663110,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668098620000434,
#   'A',
#   31104.0,
#   nan,
#   20000434,
#   1372668098,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668670620000697,
#   'A',
#   2002.0,
#   nan,
#   20000697,
#   1372668670,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667193620000432,
#   'A',
#   2002.0,
#   nan,
#   20000432,
#   1372667193,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664866620000901,
#   'C',
#   nan,
#   nan,
#   20000901,
#   1372664866,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664939620000576,
#   'C',
#   nan,
#   nan,
#   20000576,
#   1372664939,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666901620000184,
#   'B',
#   nan,
#   18.0,
#   20000184,
#   1372666901,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665035620000386,
#   'B',
#   nan,
#   15.0,
#   20000386,
#   1372665035,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665524620000542,
#   'B',
#   nan,
#   15.0,
#   20000542,
#   1372665524,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666929620000315,
#   'B',
#   nan,
#   9.0,
#   20000315,
#   1372666929,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666428620000254,
#   'A',
#   13360.0,
#   nan,
#   20000254,
#   1372666428,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665032620000541,
#   'B',
#   nan,
#   15.0,
#   20000541,
#   1372665032,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666709620000158,
#   'B',
#   nan,
#   55.0,
#   20000158,
#   1372666709,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666304620000136,
#   'B',
#   nan,
#   21.0,
#   20000136,
#   1372666304,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666958620000281,
#   'B',
#   nan,
#   32.0,
#   20000281,
#   1372666958,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665600620000406,
#   'B',
#   nan,
#   6.0,
#   20000406,
#   1372665600,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667141620000380,
#   'A',
#   2002.0,
#   nan,
#   20000380,
#   1372667141,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666136620000648,
#   'B',
#   nan,
#   18.0,
#   20000648,
#   1372666136,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665485620000617,
#   'B',
#   nan,
#   15.0,
#   20000617,
#   1372665485,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667637620000455,
#   'B',
#   nan,
#   61.0,
#   20000455,
#   1372667637,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667223620000499,
#   'B',
#   nan,
#   35.0,
#   20000499,
#   1372667223,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666613620000693,
#   'A',
#   16090.0,
#   nan,
#   20000693,
#   1372666613,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666824620000588,
#   'B',
#   nan,
#   15.0,
#   20000588,
#   1372666824,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372663152620000075,
#   'C',
#   nan,
#   nan,
#   20000075,
#   1372663152,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666748620000675,
#   'C',
#   nan,
#   nan,
#   20000675,
#   1372666748,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668731620000363,
#   'C',
#   nan,
#   nan,
#   20000363,
#   1372668731,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668618620000105,
#   'B',
#   nan,
#   36.0,
#   20000105,
#   1372668618,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665121620000235,
#   'B',
#   nan,
#   15.0,
#   20000235,
#   1372665121,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667757620000094,
#   'A',
#   7141.0,
#   nan,
#   20000094,
#   1372667757,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667629620000674,
#   'B',
#   nan,
#   13.0,
#   20000674,
#   1372667629,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665674620000021,
#   'B',
#   nan,
#   57.0,
#   20000021,
#   1372665674,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667799620000050,
#   'B',
#   nan,
#   47.0,
#   20000050,
#   1372667799,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666885620000497,
#   'A',
#   37301.0,
#   nan,
#   20000497,
#   1372666885,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666645620000249,
#   'B',
#   nan,
#   40.0,
#   20000249,
#   1372666645,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668142620000058,
#   'B',
#   nan,
#   35.0,
#   20000058,
#   1372668142,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667653620000268,
#   'B',
#   nan,
#   16.0,
#   20000268,
#   1372667653,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669784620000455,
#   'C',
#   nan,
#   nan,
#   20000455,
#   1372669784,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667907620000398,
#   'C',
#   nan,
#   nan,
#   20000398,
#   1372667907,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664004620000325,
#   'B',
#   nan,
#   14.0,
#   20000325,
#   1372664004,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665088620000186,
#   'C',
#   nan,
#   nan,
#   20000186,
#   1372665088,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667077620000230,
#   'A',
#   2002.0,
#   nan,
#   20000230,
#   1372667077,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666091620000349,
#   'B',
#   nan,
#   14.0,
#   20000349,
#   1372666091,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666772620000472,
#   'B',
#   nan,
#   15.0,
#   20000472,
#   1372666772,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372653388620000616,
#   'B',
#   nan,
#   16.0,
#   20000616,
#   1372653388,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665929620000682,
#   'A',
#   2002.0,
#   nan,
#   20000682,
#   1372665929,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667646620000508,
#   'B',
#   nan,
#   13.0,
#   20000508,
#   1372667646,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669436620000285,
#   'B',
#   nan,
#   57.0,
#   20000285,
#   1372669436,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666817620000178,
#   'B',
#   nan,
#   47.0,
#   20000178,
#   1372666817,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667894620000589,
#   'B',
#   nan,
#   36.0,
#   20000589,
#   1372667894,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372652369620000423,
#   'A',
#   53807.0,
#   nan,
#   20000423,
#   1372652369,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   12,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666306620000014,
#   'A',
#   20476.0,
#   nan,
#   20000014,
#   1372666306,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668434620000458,
#   'B',
#   nan,
#   56.0,
#   20000458,
#   1372668434,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667330620000450,
#   'A',
#   39083.0,
#   nan,
#   20000450,
#   1372667330,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664544620000596,
#   'A',
#   2002.0,
#   nan,
#   20000596,
#   1372664544,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666207620000633,
#   'B',
#   nan,
#   32.0,
#   20000633,
#   1372666207,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669271620000653,
#   'B',
#   nan,
#   13.0,
#   20000653,
#   1372669271,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667938620000480,
#   'B',
#   nan,
#   40.0,
#   20000480,
#   1372667938,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668173620000129,
#   'A',
#   60835.0,
#   nan,
#   20000129,
#   1372668173,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665998620000022,
#   'A',
#   9327.0,
#   nan,
#   20000022,
#   1372665998,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666325620000535,
#   'B',
#   nan,
#   38.0,
#   20000535,
#   1372666325,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668354620000245,
#   'B',
#   nan,
#   33.0,
#   20000245,
#   1372668354,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667821620000578,
#   'B',
#   nan,
#   54.0,
#   20000578,
#   1372667821,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372663112620000060,
#   'C',
#   nan,
#   nan,
#   20000060,
#   1372663112,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667190620000100,
#   'C',
#   nan,
#   nan,
#   20000100,
#   1372667190,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669911620000455,
#   'C',
#   nan,
#   nan,
#   20000455,
#   1372669911,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664083620000188,
#   'B',
#   nan,
#   7.0,
#   20000188,
#   1372664083,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667500620000222,
#   'B',
#   nan,
#   33.0,
#   20000222,
#   1372667500,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666301620000142,
#   'B',
#   nan,
#   18.0,
#   20000142,
#   1372666301,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665164620000502,
#   'B',
#   nan,
#   7.0,
#   20000502,
#   1372665164,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664815620000086,
#   'A',
#   2002.0,
#   nan,
#   20000086,
#   1372664815,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667632620000054,
#   'B',
#   nan,
#   9.0,
#   20000054,
#   1372667632,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669864620000050,
#   'A',
#   47219.0,
#   nan,
#   20000050,
#   1372669864,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668127620000076,
#   'C',
#   nan,
#   nan,
#   20000076,
#   1372668127,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668778620000579,
#   'B',
#   nan,
#   37.0,
#   20000579,
#   1372668778,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666972620000108,
#   'C',
#   nan,
#   nan,
#   20000108,
#   1372666972,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669904620000268,
#   'B',
#   nan,
#   18.0,
#   20000268,
#   1372669904,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666258620000049,
#   'A',
#   45427.0,
#   nan,
#   20000049,
#   1372666258,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668421620000093,
#   'B',
#   nan,
#   15.0,
#   20000093,
#   1372668421,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667454620000352,
#   'B',
#   nan,
#   21.0,
#   20000352,
#   1372667454,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669810620000075,
#   'C',
#   nan,
#   nan,
#   20000075,
#   1372669810,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669161620000195,
#   'A',
#   60725.0,
#   nan,
#   20000195,
#   1372669161,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667305620000006,
#   'B',
#   nan,
#   30.0,
#   20000006,
#   1372667305,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668819620000473,
#   'B',
#   nan,
#   6.0,
#   20000473,
#   1372668819,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669337620000074,
#   'B',
#   nan,
#   7.0,
#   20000074,
#   1372669337,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666681620000421,
#   'B',
#   nan,
#   58.0,
#   20000421,
#   1372666681,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666869620000331,
#   'B',
#   nan,
#   33.0,
#   20000331,
#   1372666869,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372655583620000569,
#   'C',
#   nan,
#   nan,
#   20000569,
#   1372655583,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   13,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665708620000118,
#   'A',
#   2002.0,
#   nan,
#   20000118,
#   1372665708,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372669604620000697,
#   'B',
#   nan,
#   19.0,
#   20000697,
#   1372669604,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   17,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372665208620000328,
#   'B',
#   nan,
#   15.0,
#   20000328,
#   1372665208,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668612620000487,
#   'B',
#   nan,
#   38.0,
#   20000487,
#   1372668612,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372667868620000341,
#   'A',
#   12246.0,
#   nan,
#   20000341,
#   1372667868,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668887620000669,
#   'B',
#   nan,
#   7.0,
#   20000669,
#   1372668887,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668264620000113,
#   'C',
#   nan,
#   nan,
#   20000113,
#   1372668264,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668303620000256,
#   'C',
#   nan,
#   nan,
#   20000256,
#   1372668303,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372668171620000678,
#   'B',
#   nan,
#   15.0,
#   20000678,
#   1372668171,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372664244620000320,
#   'C',
#   nan,
#   nan,
#   20000320,
#   1372664244,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   15,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  [1372666575620000030,
#   'B',
#   nan,
#   33.0,
#   20000030,
#   1372666575,
#   'A',
#   False,
#   0,
#   2013,
#   7,
#   1,
#   16,
#   '2013-07-01',
#   datetime.date(2013, 7, 1)],
#  ...]

# %% [markdown]
# ## 生成分片时间统计

# %%
L_depart_time=[]
for i in range(24):
    L_depart_time.append([])

count=0 
    
for row in new_source.iterrows():
    hour=row[1][12]
    temp=pointList_2[count]
    count+=1
    L_depart_time[hour].append(temp)

# %%
print(len(L_depart_time))
# Out:
# 24

# %% [markdown]
# ## 写入csv文件

# %%
for hour in range(24):
    filename="./TimeData/"+str(hour)+".csv"
    
    f_time_write=csv.writer(open(filename,'w', newline=''))
 
    L_title=['lng','lan','number']
    f_time_write.writerow(L_title)
    
    for item in L_depart_time[hour]:
        f_time_write.writerow(item)
